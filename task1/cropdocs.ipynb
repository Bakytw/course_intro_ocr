# %%
from pathlib import Path
from course_intro_ocr_t1.data import MidvPackage
from tqdm import tqdm
import numpy as np
import cv2

# %%
DATASET_PATH = Path().absolute().parent.parent / 'midv500' / 'midv500_compressed'
assert DATASET_PATH.exists(), DATASET_PATH.absolute()

# %%
# Собираем список пакетов (MidvPackage) 
data_packs = MidvPackage.read_midv500_dataset(DATASET_PATH)
len(data_packs), type(data_packs[0])
# Out:
# (50, course_intro_ocr_t1.data.MidvPackage)

# %%
class Cropper:
    def __init__(self):
        self.sift = cv2.SIFT_create()
        
    def preprocess_image(self, img):
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        return gray_img
        
    def detect_compute_keypoints_descriptors(self, img):
        keypoints = self.sift.detect(img, None)
        keypoints, descriptors = self.sift.compute(img, keypoints)
        return keypoints, descriptors
        
    def match_keypoints(self, template_dscs, target_dscs):
        matches = cv2.FlannBasedMatcher(dict(algorithm=0, trees=5), dict(checks=50)).knnMatch(template_dscs, target_dscs, k=2)
        distances = np.array([m.distance for m, n in matches])
        matches = [matches[i][0] for i in np.where(distances < 0.5 * np.roll(distances, -1))[0]]
        return matches
        
    def find_homography(self, query_pts, train_pts):
        homo, _ = cv2.findHomography(query_pts, train_pts, cv2.RANSAC, 5.0)
        return homo
        
    def transform_angles(self, homo, template_img):
        template_angles = np.array([[0, 0], [len(template_img[0]), 0], [len(template_img[0]), len(template_img)], [0, len(template_img)]], dtype=np.float32)[:, None]
        transformed_angles = cv2.perspectiveTransform(template_angles, homo)
        return transformed_angles
        
    def normalize_coordinates(self, angles, target_img):
        return angles / np.array([len(target_img[0]), len(target_img)])
        
    def angles(self, template_img, target_img):
        template_gray = self.preprocess_image(template_img)
        target_gray = self.preprocess_image(target_img)
        template_kpts, template_dscs = self.detect_compute_keypoints_descriptors(template_gray)
        target_kpts, target_dscs = self.detect_compute_keypoints_descriptors(target_gray)
        matches = self.match_keypoints(template_dscs, target_dscs)
        homo = self.find_homography(np.array([template_kpts[m.queryIdx].pt for m in matches], dtype=np.float32)[:, None],
                                       np.array([target_kpts[m.trainIdx].pt for m in matches], dtype=np.float32)[:, None])
        transformed_angles = self.transform_angles(homo, template_img)
        normalized_angles = self.normalize_coordinates(transformed_angles, target_img)
        return normalized_angles

    def process_data_packs(self, data_packs):
        results_dict = {}
        for dp in tqdm(data_packs):
            for i in range(len(dp)):
                if dp[i].is_test_split():
                    try:
                        results_dict[dp[i].unique_key] = self.angles(np.array(dp.template_item.image), np.array(dp[i].image))
                    except Exception as exc:
                        print(exc)
        return results_dict

# %%
cropper = Cropper()
results_dict = cropper.process_data_packs(data_packs)
output_dict = {key: arr.squeeze() for key, arr in results_dict.items()}
# Out:
#  50%|█████     | 25/50 [09:31<10:05, 24.20s/it]
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\matmul.dispatch.cpp:550: error: (-215:Assertion failed) scn + 1 == m.cols in function 'cv::perspectiveTransform'
#  96%|█████████▌| 48/50 [26:50<03:55, 117.96s/it]
# OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\matmul.dispatch.cpp:550: error: (-215:Assertion failed) scn + 1 == m.cols in function 'cv::perspectiveTransform'
# 100%|██████████| 50/50 [31:18<00:00, 37.57s/it]

# %% [markdown]
# ## Узнаем точность

# %%
output_dict
# Out:
# {'01_alb_id|ground_truth|CA|CA01_26.json': array([[0.05510424, 0.33678593],
#         [0.84211548, 0.31808861],
#         [0.86882243, 0.59175728],
#         [0.08149398, 0.61886978]]),
#  '01_alb_id|ground_truth|CA|CA01_27.json': array([[0.07105584, 0.34295792],
#         [0.83816678, 0.32471367],
#         [0.86455946, 0.59250301],
#         [0.09599744, 0.61905407]]),
#  '01_alb_id|ground_truth|CA|CA01_28.json': array([[0.08542291, 0.35124588],
#         [0.83783576, 0.33378422],
#         [0.86391378, 0.59590126],
#         [0.10968011, 0.621759  ]]),
#  '01_alb_id|ground_truth|CA|CA01_29.json': array([[0.08869185, 0.35223263],
#         [0.83965658, 0.33720261],
#         [0.86647244, 0.59860241],
#         [0.1132111 , 0.62324764]]),
#  '01_alb_id|ground_truth|CA|CA01_30.json': array([[0.07679771, 0.33745579],
#         [0.85077989, 0.32396103],
#         [0.8785456 , 0.59278896],
#         [0.10260929, 0.61621571]]),
#  '01_alb_id|ground_truth|CS|CS01_26.json': array([[0.11950849, 0.41244068],
#         [0.93087063, 0.43656116],
#         [0.94115648, 0.73251259],
#         [0.04859772, 0.70665749]]),
#  '01_alb_id|ground_truth|CS|CS01_27.json': array([[0.09764998, 0.43096317],
#         [0.91365187, 0.45355328],
#         [0.9223447 , 0.75020325],
#         [0.02734792, 0.72955276]]),
#  '01_alb_id|ground_truth|CS|CS01_28.json': array([[0.10336283, 0.41931824],
#         [0.91547777, 0.44993935],
#         [0.92364868, 0.75384483],
#         [0.03841814, 0.72092148]]),
#  '01_alb_id|ground_truth|CS|CS01_29.json': array([[0.11359173, 0.4140947 ],
#         [0.94330838, 0.44106121],
#         [0.94551921, 0.74628197],
#         [0.04602278, 0.71704742]]),
#  '01_alb_id|ground_truth|CS|CS01_30.json': array([[0.11719443, 0.39366413],
#         [0.95764452, 0.4270742 ],
#         [0.95313402, 0.73691544],
#         [0.05302882, 0.6993515 ]]),
#  '01_alb_id|ground_truth|HA|HA01_26.json': array([[0.76680745, 0.8284446 ],
#         [0.76774129, 0.78232071],
#         [0.61464308, 0.86213661],
#         [0.76212029, 0.77855507]]),
#  '01_alb_id|ground_truth|HA|HA01_27.json': array([[ 0.1553103 ,  0.43404808],
#         [ 1.00374749,  0.58547218],
#         [ 0.82888692,  0.85880745],
#         [-0.0032945 ,  0.73991516]]),
#  '01_alb_id|ground_truth|HA|HA01_28.json': array([[ 0.13857224,  0.41237949],
#         [ 1.0342414 ,  0.54943096],
#         [ 0.84806295,  0.82446053],
#         [-0.00243531,  0.7217292 ]]),
#  '01_alb_id|ground_truth|HA|HA01_29.json': array([[ 0.12139771,  0.39692482],
#         [ 1.0322035 ,  0.51937378],
#         [ 0.85145494,  0.7934153 ],
#         [-0.00146072,  0.710065  ]]),
#  '01_alb_id|ground_truth|HA|HA01_30.json': array([[ 0.07220636,  0.3897348 ],
#         [ 0.99777161,  0.49514286],
#         [ 0.83299615,  0.77113029],
#         [-0.02988493,  0.70468185]]),
#  '01_alb_id|ground_truth|HS|HS01_26.json': array([[0.041096  , 0.40134045],
#         [0.81306898, 0.38572086],
#         [0.84517944, 0.65627541],
#         [0.06197676, 0.6841555 ]]),
#  '01_alb_id|ground_truth|HS|HS01_27.json': array([[0.08560993, 0.40641186],
#         [0.86193658, 0.39521568],
#         [0.89093933, 0.67327461],
#         [0.08716385, 0.69960297]]),
#  '01_alb_id|ground_truth|HS|HS01_28.json': array([[0.11570492, 0.41485779],
#         [0.89982137, 0.41271297],
#         [0.90626166, 0.68490547],
#         [0.11925352, 0.69953888]]),
#  '01_alb_id|ground_truth|HS|HS01_29.json': array([[0.12246913, 0.42715858],
#         [0.88359931, 0.4263694 ],
#         [0.8891057 , 0.6898172 ],
#         [0.12209217, 0.70469933]]),
#  '01_alb_id|ground_truth|HS|HS01_30.json': array([[0.12031469, 0.44561134],
#         [0.8652714 , 0.44594456],
#         [0.87544807, 0.70608139],
#         [0.1178827 , 0.71815704]]),
#  '01_alb_id|ground_truth|KA|KA01_26.json': array([[0.00850341, 0.18032782],
#         [0.9174353 , 0.14226409],
#         [0.92934374, 0.46261593],
#         [0.08143008, 0.48899422]]),
#  '01_alb_id|ground_truth|KA|KA01_27.json': array([[0.01111649, 0.1644434 ],
#         [0.91880751, 0.12855631],
#         [0.92865614, 0.44992615],
#         [0.08119576, 0.47561726]]),
#  '01_alb_id|ground_truth|KA|KA01_28.json': array([[0.02779566, 0.15967062],
#         [0.93280965, 0.12300393],
#         [0.9371538 , 0.44339676],
#         [0.09654923, 0.46850933]]),
#  '01_alb_id|ground_truth|KA|KA01_29.json': array([[0.03897675, 0.15537686],
#         [0.94538662, 0.12220839],
#         [0.94508735, 0.44182926],
#         [0.10461028, 0.46381908]]),
#  '01_alb_id|ground_truth|KA|KA01_30.json': array([[0.0323022 , 0.14300278],
#         [0.94777724, 0.1166816 ],
#         [0.9428833 , 0.43535236],
#         [0.10004625, 0.45408718]]),
#  '01_alb_id|ground_truth|KS|KS01_26.json': array([[0.04366625, 0.39875641],
#         [0.90342387, 0.41344662],
#         [0.91180949, 0.71708069],
#         [0.01713697, 0.71313812]]),
#  '01_alb_id|ground_truth|KS|KS01_27.json': array([[0.04931237, 0.39218548],
#         [0.90266893, 0.40866825],
#         [0.91048699, 0.71050301],
#         [0.02225202, 0.70480911]]),
#  '01_alb_id|ground_truth|KS|KS01_28.json': array([[0.05147702, 0.38752792],
#         [0.89885301, 0.4043634 ],
#         [0.90619853, 0.7025457 ],
#         [0.02213315, 0.69812218]]),
#  '01_alb_id|ground_truth|KS|KS01_29.json': array([[0.0558162 , 0.38454422],
#         [0.89296889, 0.40344063],
#         [0.90099752, 0.69794563],
#         [0.02579992, 0.69418686]]),
#  '01_alb_id|ground_truth|KS|KS01_30.json': array([[0.04963615, 0.37935116],
#         [0.88626662, 0.40301155],
#         [0.89319973, 0.69404701],
#         [0.02017708, 0.6899704 ]]),
#  '01_alb_id|ground_truth|PA|PA01_26.json': array([[0.03393881, 0.37830742],
#         [0.91973999, 0.35203297],
#         [0.98753825, 0.66170303],
#         [0.00310891, 0.68317589]]),
#  '01_alb_id|ground_truth|PA|PA01_27.json': array([[ 0.01326992,  0.38639912],
#         [ 0.87993578,  0.35949448],
#         [ 0.95198391,  0.65759659],
#         [-0.02438859,  0.68458176]]),
#  '01_alb_id|ground_truth|PA|PA01_28.json': array([[-0.00212697,  0.3934959 ],
#         [ 0.85430617,  0.38326145],
#         [ 0.91771952,  0.67723091],
#         [-0.03675552,  0.69602097]]),
#  '01_alb_id|ground_truth|PA|PA01_29.json': array([[-0.00551277,  0.38774658],
#         [ 0.84544807,  0.403643  ],
#         [ 0.91011936,  0.69313568],
#         [-0.04256238,  0.69756836]]),
#  '01_alb_id|ground_truth|PA|PA01_30.json': array([[-0.00599539,  0.37282612],
#         [ 0.87894104,  0.37227032],
#         [ 0.94603773,  0.67713882],
#         [-0.03334296,  0.69254944]]),
#  '01_alb_id|ground_truth|PS|PS01_26.json': array([[0.11534765, 0.16250776],
#         [0.939823  , 0.17672886],
#         [0.95264757, 0.45497211],
#         [0.03975906, 0.43197155]]),
#  '01_alb_id|ground_truth|PS|PS01_27.json': array([[0.12797479, 0.15990095],
#         [0.9483195 , 0.17254044],
#         [0.9581387 , 0.44848877],
#         [0.05233941, 0.42560818]]),
#  '01_alb_id|ground_truth|PS|PS01_28.json': array([[0.13652213, 0.15516021],
#         [0.95129734, 0.17016874],
#         [0.95845595, 0.4433984 ],
#         [0.06101242, 0.41864574]]),
#  '01_alb_id|ground_truth|PS|PS01_29.json': array([[0.13768248, 0.14673645],
#         [0.95290853, 0.16144781],
#         [0.9600257 , 0.43432426],
#         [0.06157628, 0.40959759]]),
#  '01_alb_id|ground_truth|PS|PS01_30.json': array([[0.13197495, 0.13406354],
#         [0.95202298, 0.15027142],
#         [0.95695468, 0.42293201],
#         [0.05545784, 0.39740677]]),
#  '01_alb_id|ground_truth|TA|TA01_26.json': array([[0.20131375, 0.26306477],
#         [0.98239617, 0.41737282],
#         [0.80709724, 0.70212212],
#         [0.01887055, 0.53401993]]),
#  '01_alb_id|ground_truth|TA|TA01_27.json': array([[0.19208026, 0.26098911],
#         [0.97278246, 0.41561928],
#         [0.78879103, 0.69532677],
#         [0.01245001, 0.52898136]]),
#  '01_alb_id|ground_truth|TA|TA01_28.json': array([[0.19129405, 0.25611443],
#         [0.95749376, 0.40912441],
#         [0.78336962, 0.687472  ],
#         [0.01367531, 0.52163185]]),
#  '01_alb_id|ground_truth|TA|TA01_29.json': array([[0.19747104, 0.24745861],
#         [0.95635173, 0.39942554],
#         [0.77979574, 0.67343895],
#         [0.01995108, 0.50896564]]),
#  '01_alb_id|ground_truth|TA|TA01_30.json': array([[0.19786577, 0.2343952 ],
#         [0.95240356, 0.38561367],
#         [0.7753732 , 0.65776047],
#         [0.0207656 , 0.49360428]]),
#  '01_alb_id|ground_truth|TS|TS01_26.json': array([[0.05312147, 0.38638435],
#         [0.94353346, 0.39931736],
#         [0.94898844, 0.70826279],
#         [0.04153345, 0.71637978]]),
#  '01_alb_id|ground_truth|TS|TS01_27.json': array([[0.05897729, 0.38029545],
#         [0.95416714, 0.39555542],
#         [0.95850023, 0.70657623],
#         [0.04620488, 0.71228981]]),
#  '01_alb_id|ground_truth|TS|TS01_28.json': array([[0.05750153, 0.37964939],
#         [0.95718438, 0.39309086],
#         [0.96097378, 0.70451767],
#         [0.04424838, 0.7112204 ]]),
#  '01_alb_id|ground_truth|TS|TS01_29.json': array([[0.04730484, 0.37779327],
#         [0.95145487, 0.39175636],
#         [0.95578152, 0.70420944],
#         [0.03536987, 0.71110634]]),
#  '01_alb_id|ground_truth|TS|TS01_30.json': array([[0.04938405, 0.37243954],
#         [0.9510418 , 0.38826408],
#         [0.9550748 , 0.70039452],
#         [0.03631317, 0.704646  ]]),
#  '02_aut_drvlic_new|ground_truth|CA|CA02_26.json': array([[0.0446722 , 0.5446373 ],
#         [0.77800151, 0.41599197],
#         [0.92360908, 0.6724427 ],
#         [0.19223038, 0.80797668]]),
#  '02_aut_drvlic_new|ground_truth|CA|CA02_27.json': array([[0.03902514, 0.54475445],
#         [0.77093018, 0.41460911],
#         [0.91956292, 0.67151321],
#         [0.18596615, 0.80870552]]),
#  '02_aut_drvlic_new|ground_truth|CA|CA02_28.json': array([[0.03614161, 0.5421867 ],
#         [0.7635494 , 0.41232212],
#         [0.91468974, 0.66845085],
#         [0.18223316, 0.80553574]]),
#  '02_aut_drvlic_new|ground_truth|CA|CA02_29.json': array([[0.0353734 , 0.53345425],
#         [0.75936666, 0.40534256],
#         [0.91107666, 0.66057365],
#         [0.18175749, 0.79592796]]),
#  '02_aut_drvlic_new|ground_truth|CA|CA02_30.json': array([[0.04064346, 0.52610085],
#         [0.7586402 , 0.39663094],
#         [0.91092244, 0.65057686],
#         [0.18659327, 0.78695663]]),
#  '02_aut_drvlic_new|ground_truth|CS|CS02_26.json': array([[0.06760662, 0.05089348],
#         [0.79532349, 0.10067047],
#         [0.81871216, 0.34818329],
#         [0.04250635, 0.31629957]]),
#  '02_aut_drvlic_new|ground_truth|CS|CS02_27.json': array([[0.05375476, 0.03198269],
#         [0.82648722, 0.08044903],
#         [0.84378486, 0.33267395],
#         [0.04309272, 0.31061316]]),
#  '02_aut_drvlic_new|ground_truth|CS|CS02_28.json': array([[0.02167173, 0.01576428],
#         [0.83349982, 0.06118661],
#         [0.86044508, 0.32430111],
#         [0.00883306, 0.30517508]]),
#  '02_aut_drvlic_new|ground_truth|CS|CS02_29.json': array([[-0.0227768 ,  0.0183175 ],
#         [ 0.80897637,  0.04935228],
#         [ 0.84804389,  0.32026379],
#         [-0.02926058,  0.31270803]]),
#  '02_aut_drvlic_new|ground_truth|CS|CS02_30.json': array([[-0.0437755 ,  0.02613319],
#         [ 0.79104662,  0.05372943],
#         [ 0.83463677,  0.32795643],
#         [-0.05178724,  0.32172035]]),
#  '02_aut_drvlic_new|ground_truth|HA|HA02_26.json': array([[0.15615363, 0.31967306],
#         [0.92523349, 0.39415764],
#         [0.90907491, 0.66585327],
#         [0.07578199, 0.60547745]]),
#  '02_aut_drvlic_new|ground_truth|HA|HA02_27.json': array([[0.11103054, 0.33102047],
#         [0.89603163, 0.36559731],
#         [0.91566888, 0.63749756],
#         [0.07914378, 0.62037628]]),
#  '02_aut_drvlic_new|ground_truth|HA|HA02_28.json': array([[0.07826648, 0.344921  ],
#         [0.86253255, 0.34982719],
#         [0.90843709, 0.62136612],
#         [0.07914987, 0.63677116]]),
#  '02_aut_drvlic_new|ground_truth|HA|HA02_29.json': array([[0.07789261, 0.35928276],
#         [0.8529381 , 0.35291813],
#         [0.91757785, 0.6211758 ],
#         [0.08398259, 0.64563362]]),
#  '02_aut_drvlic_new|ground_truth|HA|HA02_30.json': array([[0.07659328, 0.37170639],
#         [0.85511773, 0.35554077],
#         [0.94698513, 0.61605213],
#         [0.08632115, 0.65022545]]),
#  '02_aut_drvlic_new|ground_truth|HS|HS02_26.json': array([[0.03420074, 0.43302776],
#         [0.9162085 , 0.31841917],
#         [1.04896016, 0.64457359],
#         [0.13042967, 0.74728737]]),
#  '02_aut_drvlic_new|ground_truth|HS|HS02_27.json': array([[0.25385042, 0.92702667],
#         [0.25377519, 0.92704811],
#         [0.2565893 , 0.9252549 ],
#         [0.25378535, 0.92703354]]),
#  '02_aut_drvlic_new|ground_truth|HS|HS02_28.json': array([[ 0.05064827,  0.40924725],
#         [ 0.92717333,  0.48781067],
#         [ 0.82685615,  0.82908363],
#         [-0.03895737,  0.7097361 ]]),
#  '02_aut_drvlic_new|ground_truth|HS|HS02_29.json': array([[0.09336008, 0.43375343],
#         [0.90701999, 0.47123623],
#         [0.85618449, 0.78664162],
#         [0.03559146, 0.71942047]]),
#  '02_aut_drvlic_new|ground_truth|HS|HS02_30.json': array([[0.10943016, 0.42564808],
#         [0.90404677, 0.44475048],
#         [0.87683404, 0.72920135],
#         [0.10137583, 0.70244431]]),
#  '02_aut_drvlic_new|ground_truth|KA|KA02_26.json': array([[ 0.04254813,  0.24982321],
#         [ 0.73464247,  0.30575443],
#         [ 0.69024407,  0.54340218],
#         [-0.00234225,  0.50662773]]),
#  '02_aut_drvlic_new|ground_truth|KA|KA02_27.json': array([[ 0.03935566,  0.24808174],
#         [ 0.72658203,  0.30568586],
#         [ 0.67997986,  0.54112553],
#         [-0.00679502,  0.50426399]]),
#  '02_aut_drvlic_new|ground_truth|KA|KA02_28.json': array([[0.05319067, 0.25211588],
#         [0.73196818, 0.30969028],
#         [0.68430291, 0.54465908],
#         [0.00357426, 0.50537636]]),
#  '02_aut_drvlic_new|ground_truth|KA|KA02_29.json': array([[0.06174707, 0.25602625],
#         [0.73374308, 0.31557552],
#         [0.68877896, 0.55051811],
#         [0.00781001, 0.50918327]]),
#  '02_aut_drvlic_new|ground_truth|KA|KA02_30.json': array([[0.05825213, 0.25454424],
#         [0.73653259, 0.31751711],
#         [0.6833433 , 0.54935776],
#         [0.00818272, 0.50798378]]),
#  '02_aut_drvlic_new|ground_truth|KS|KS02_26.json': array([[0.07139657, 0.30295803],
#         [0.92348375, 0.31050556],
#         [0.93324992, 0.61366093],
#         [0.05012049, 0.61007755]]),
#  '02_aut_drvlic_new|ground_truth|KS|KS02_27.json': array([[0.09613808, 0.30744518],
#         [0.93420892, 0.31699404],
#         [0.94081855, 0.61546284],
#         [0.07365114, 0.61171543]]),
#  '02_aut_drvlic_new|ground_truth|KS|KS02_28.json': array([[0.09682824, 0.29764936],
#         [0.96038506, 0.30826384],
#         [0.9738878 , 0.61421089],
#         [0.07174512, 0.60773041]]),
#  '02_aut_drvlic_new|ground_truth|KS|KS02_29.json': array([[0.07837107, 0.28787392],
#         [0.95890198, 0.29921564],
#         [0.96968472, 0.6101305 ],
#         [0.05210069, 0.60113075]]),
#  '02_aut_drvlic_new|ground_truth|KS|KS02_30.json': array([[0.07079748, 0.28420362],
#         [0.95092787, 0.29165861],
#         [0.96495734, 0.60378582],
#         [0.04382816, 0.59884705]]),
#  '02_aut_drvlic_new|ground_truth|PA|PA02_26.json': array([[0.65271254, 0.51736977],
#         [0.64358948, 0.50345505],
#         [0.65328403, 0.5183358 ],
#         [0.64946832, 0.51251411]]),
#  '02_aut_drvlic_new|ground_truth|PA|PA02_27.json': array([[0.22701104, 0.41188709],
#         [0.25729904, 0.43192989],
#         [0.21682366, 0.40548794],
#         [0.13626112, 0.35335014]]),
#  '02_aut_drvlic_new|ground_truth|PA|PA02_28.json': array([[ 0.01114995,  0.43088661],
#         [ 0.00058948,  0.42488121],
#         [ 0.01246201,  0.43181141],
#         [-0.03388417,  0.40857464]]),
#  '02_aut_drvlic_new|ground_truth|PA|PA02_29.json': array([[0.37817549, 0.34220505],
#         [0.36966593, 0.32476074],
#         [0.3711792 , 0.34089745],
#         [0.38635267, 0.27855024]]),
#  '02_aut_drvlic_new|ground_truth|PA|PA02_30.json': array([[-0.06612264,  0.24316446],
#         [ 0.81387404,  0.19095314],
#         [ 0.85700684,  0.50076145],
#         [ 0.02669925,  0.54806973]]),
#  '02_aut_drvlic_new|ground_truth|PS|PS02_26.json': array([[0.2372543 , 0.36372616],
#         [1.00088338, 0.38793083],
#         [0.94469767, 0.67143127],
#         [0.18633767, 0.62882607]]),
#  '02_aut_drvlic_new|ground_truth|PS|PS02_27.json': array([[0.23986976, 0.35599369],
#         [1.03252672, 0.38546009],
#         [0.97861138, 0.69370682],
#         [0.17575706, 0.62327736]]),
#  '02_aut_drvlic_new|ground_truth|PS|PS02_28.json': array([[0.31656989, 0.69468697],
#         [0.31558387, 0.69579811],
#         [0.31674188, 0.69467964],
#         [0.31674835, 0.69470436]]),
#  '02_aut_drvlic_new|ground_truth|PS|PS02_29.json': array([[0.061581  , 0.1736516 ],
#         [0.0549448 , 0.1704801 ],
#         [0.06328848, 0.18660437],
#         [0.05800482, 0.17379204]]),
#  '02_aut_drvlic_new|ground_truth|PS|PS02_30.json': array([[0.22072362, 0.38112438],
#         [1.00056003, 0.41576237],
#         [0.9327474 , 0.72089584],
#         [0.16825021, 0.63864937]]),
#  '02_aut_drvlic_new|ground_truth|TA|TA02_26.json': array([[0.10490357, 0.23470871],
#         [0.94487664, 0.27240433],
#         [0.91409532, 0.56979504],
#         [0.05175721, 0.53155712]]),
#  '02_aut_drvlic_new|ground_truth|TA|TA02_27.json': array([[0.10984388, 0.23994738],
#         [0.94147325, 0.27785192],
#         [0.91287211, 0.57210026],
#         [0.05620315, 0.53405006]]),
#  '02_aut_drvlic_new|ground_truth|TA|TA02_28.json': array([[0.06898875, 0.21952162],
#         [0.94266439, 0.26308414],
#         [0.91210565, 0.56761482],
#         [0.01556624, 0.52681671]]),
#  '02_aut_drvlic_new|ground_truth|TA|TA02_29.json': array([[0.05534381, 0.19576603],
#         [0.94478706, 0.23783369],
#         [0.91504781, 0.5529715 ],
#         [0.00123141, 0.51065678]]),
#  '02_aut_drvlic_new|ground_truth|TA|TA02_30.json': array([[0.06901616, 0.19723307],
#         [0.94582621, 0.23449493],
#         [0.91544617, 0.54715767],
#         [0.01498428, 0.50736187]]),
#  '02_aut_drvlic_new|ground_truth|TS|TS02_26.json': array([[0.01992967, 0.36483967],
#         [0.86447645, 0.37578777],
#         [0.88420241, 0.66367867],
#         [0.01710395, 0.68952271]]),
#  '02_aut_drvlic_new|ground_truth|TS|TS02_27.json': array([[0.0279083 , 0.36811924],
#         [0.883966  , 0.37851086],
#         [0.89866428, 0.67047783],
#         [0.02465238, 0.69851486]]),
#  '02_aut_drvlic_new|ground_truth|TS|TS02_28.json': array([[0.02102347, 0.38404232],
#         [0.88553026, 0.39251896],
#         [0.89956021, 0.68693001],
#         [0.01743972, 0.71881943]]),
#  '02_aut_drvlic_new|ground_truth|TS|TS02_29.json': array([[0.01279917, 0.4032814 ],
#         [0.88019972, 0.41070198],
#         [0.89361477, 0.70506477],
#         [0.01012379, 0.74250755]]),
#  '02_aut_drvlic_new|ground_truth|TS|TS02_30.json': array([[0.01100828, 0.4191991 ],
#         [0.88423781, 0.42549721],
#         [0.89896172, 0.72248802],
#         [0.00960438, 0.76317635]]),
#  '03_aut_id_old|ground_truth|CA|CA03_26.json': array([[0.08379092, 0.43572319],
#         [0.70648573, 0.28323044],
#         [0.87340915, 0.50863541],
#         [0.24235969, 0.65029198]]),
#  '03_aut_id_old|ground_truth|CA|CA03_27.json': array([[0.0810332 , 0.42697651],
#         [0.71257372, 0.2764147 ],
#         [0.87635098, 0.50443501],
#         [0.24015042, 0.64446541]]),
#  '03_aut_id_old|ground_truth|CA|CA03_28.json': array([[0.08194644, 0.41509651],
#         [0.72315199, 0.26584692],
#         [0.88153815, 0.49703838],
#         [0.24167175, 0.63465469]]),
#  '03_aut_id_old|ground_truth|CA|CA03_29.json': array([[0.07298454, 0.39460018],
#         [0.7380702 , 0.24691246],
#         [0.8894774 , 0.48364536],
#         [0.23927366, 0.61899418]]),
#  '03_aut_id_old|ground_truth|CA|CA03_30.json': array([[0.07202304, 0.36979427],
#         [0.74723674, 0.21742224],
#         [0.90623678, 0.46250874],
#         [0.22997759, 0.59770962]]),
#  '03_aut_id_old|ground_truth|CS|CS03_26.json': array([[0.13446209, 0.57889683],
#         [0.84835029, 0.57633404],
#         [0.93432773, 0.83587265],
#         [0.10889516, 0.87123756]]),
#  '03_aut_id_old|ground_truth|CS|CS03_27.json': array([[0.13557988, 0.57851776],
#         [0.85234158, 0.58160324],
#         [0.9281743 , 0.8414016 ],
#         [0.10205812, 0.86891258]]),
#  '03_aut_id_old|ground_truth|CS|CS03_28.json': array([[0.13586935, 0.57309826],
#         [0.85316101, 0.58418041],
#         [0.92380751, 0.84698311],
#         [0.09513983, 0.8655687 ]]),
#  '03_aut_id_old|ground_truth|CS|CS03_29.json': array([[0.12985047, 0.57135445],
#         [0.85346368, 0.58238892],
#         [0.91728916, 0.84696747],
#         [0.08376591, 0.86505501]]),
#  '03_aut_id_old|ground_truth|CS|CS03_30.json': array([[0.12821566, 0.57395782],
#         [0.85531759, 0.58890617],
#         [0.91339023, 0.85477623],
#         [0.07624303, 0.86775436]]),
#  '03_aut_id_old|ground_truth|HA|HA03_26.json': array([[0.05263259, 0.43604908],
#         [0.86370334, 0.2989011 ],
#         [1.04783875, 0.57243866],
#         [0.15951146, 0.71971382]]),
#  '03_aut_id_old|ground_truth|HA|HA03_27.json': array([[0.05246954, 0.43713173],
#         [0.86466275, 0.30121649],
#         [1.0432567 , 0.57767113],
#         [0.16642134, 0.72224197]]),
#  '03_aut_id_old|ground_truth|HA|HA03_28.json': array([[0.05479272, 0.43863758],
#         [0.86782762, 0.30098555],
#         [1.03303535, 0.58699448],
#         [0.17962102, 0.72341278]]),
#  '03_aut_id_old|ground_truth|HA|HA03_29.json': array([[0.05200703, 0.44011036],
#         [0.87121101, 0.30689686],
#         [1.02104533, 0.59735996],
#         [0.18399334, 0.72322922]]),
#  '03_aut_id_old|ground_truth|HA|HA03_30.json': array([[0.04636866, 0.43961189],
#         [0.8725472 , 0.31755842],
#         [1.0014072 , 0.60930229],
#         [0.17833408, 0.71802124]]),
#  '03_aut_id_old|ground_truth|HS|HS03_26.json': array([[0.09219588, 0.40836315],
#         [0.84244534, 0.39353245],
#         [0.86478177, 0.6468573 ],
#         [0.11041053, 0.67591766]]),
#  '03_aut_id_old|ground_truth|HS|HS03_27.json': array([[0.09638017, 0.41618252],
#         [0.85038662, 0.39922745],
#         [0.86828918, 0.65485008],
#         [0.11715515, 0.68200035]]),
#  '03_aut_id_old|ground_truth|HS|HS03_28.json': array([[0.09012547, 0.42214809],
#         [0.84986864, 0.40663158],
#         [0.86756802, 0.66366829],
#         [0.10953529, 0.68846817]]),
#  '03_aut_id_old|ground_truth|HS|HS03_29.json': array([[0.07960802, 0.41822098],
#         [0.85257819, 0.40685413],
#         [0.86934326, 0.6684832 ],
#         [0.09576067, 0.69102577]]),
#  '03_aut_id_old|ground_truth|HS|HS03_30.json': array([[0.06216149, 0.40619804],
#         [0.85740377, 0.39707321],
#         [0.8801688 , 0.66741821],
#         [0.07359806, 0.68917763]]),
#  '03_aut_id_old|ground_truth|KA|KA03_26.json': array([[0.1717846 , 0.45965286],
#         [0.88718981, 0.55826389],
#         [0.77982727, 0.81452148],
#         [0.05016636, 0.70696968]]),
#  '03_aut_id_old|ground_truth|KA|KA03_27.json': array([[0.16026898, 0.46959839],
#         [0.872995  , 0.56867905],
#         [0.76602804, 0.82438774],
#         [0.03975949, 0.71740021]]),
#  '03_aut_id_old|ground_truth|KA|KA03_28.json': array([[0.16394235, 0.47823395],
#         [0.86916497, 0.57527328],
#         [0.75956977, 0.82922066],
#         [0.04360647, 0.72503662]]),
#  '03_aut_id_old|ground_truth|KA|KA03_29.json': array([[0.17232346, 0.49594173],
#         [0.85658963, 0.58714649],
#         [0.77082818, 0.83958023],
#         [0.052505  , 0.73906837]]),
#  '03_aut_id_old|ground_truth|KA|KA03_30.json': array([[0.18661174, 0.50727821],
#         [0.88166077, 0.59877026],
#         [0.78259711, 0.85358879],
#         [0.06879821, 0.75179871]]),
#  '03_aut_id_old|ground_truth|KS|KS03_26.json': array([[0.08039637, 0.25791681],
#         [0.87969889, 0.27141031],
#         [0.8527396 , 0.56377396],
#         [0.04808631, 0.5279681 ]]),
#  '03_aut_id_old|ground_truth|KS|KS03_27.json': array([[0.07168731, 0.25566544],
#         [0.87241218, 0.26790976],
#         [0.84101563, 0.55454029],
#         [0.04556177, 0.52728642]]),
#  '03_aut_id_old|ground_truth|KS|KS03_28.json': array([[0.07125584, 0.26227795],
#         [0.87828505, 0.27036951],
#         [0.85032179, 0.55677483],
#         [0.04973003, 0.53451771]]),
#  '03_aut_id_old|ground_truth|KS|KS03_29.json': array([[0.07433665, 0.26918022],
#         [0.87599589, 0.27551933],
#         [0.85154616, 0.56041672],
#         [0.0562301 , 0.54188416]]),
#  '03_aut_id_old|ground_truth|KS|KS03_30.json': array([[0.06535308, 0.27682634],
#         [0.87571974, 0.28063314],
#         [0.85463142, 0.56381901],
#         [0.05462051, 0.55039665]]),
#  '03_aut_id_old|ground_truth|PA|PA03_26.json': array([[-0.03069684,  0.39067192],
#         [ 0.9807451 ,  0.34445801],
#         [ 1.02504232,  0.68932671],
#         [ 0.02255222,  0.73753433]]),
#  '03_aut_id_old|ground_truth|PA|PA03_27.json': array([[-0.05553648,  0.39894875],
#         [ 0.94663249,  0.34960644],
#         [ 0.98761841,  0.6871225 ],
#         [ 0.00271343,  0.73782166]]),
#  '03_aut_id_old|ground_truth|PA|PA03_28.json': array([[-0.11152733,  0.41150089],
#         [ 0.85567369,  0.33794987],
#         [ 0.92893277,  0.6639109 ],
#         [-0.02628668,  0.74155159]]),
#  '03_aut_id_old|ground_truth|PA|PA03_29.json': array([[-0.12704237,  0.4266106 ],
#         [ 0.80661987,  0.33504658],
#         [ 0.90640489,  0.65160774],
#         [-0.02038575,  0.74975494]]),
#  '03_aut_id_old|ground_truth|PA|PA03_30.json': array([[-0.11670045,  0.43479851],
#         [ 0.78872477,  0.3133132 ],
#         [ 0.9188975 ,  0.62563095],
#         [ 0.01892718,  0.75063194]]),
#  '03_aut_id_old|ground_truth|PS|PS03_26.json': array([[0.12053476, 0.0953322 ],
#         [1.05245205, 0.09931185],
#         [1.05569309, 0.41278267],
#         [0.16062515, 0.43589333]]),
#  '03_aut_id_old|ground_truth|PS|PS03_27.json': array([[0.07103574, 0.12162764],
#         [0.98401706, 0.12836634],
#         [0.98513502, 0.4321981 ],
#         [0.11323506, 0.45364071]]),
#  '03_aut_id_old|ground_truth|PS|PS03_28.json': array([[0.03700654, 0.12052488],
#         [0.95390896, 0.13510765],
#         [0.95957425, 0.43545143],
#         [0.07559162, 0.45034466]]),
#  '03_aut_id_old|ground_truth|PS|PS03_29.json': array([[0.03679239, 0.09425717],
#         [0.96182461, 0.11229483],
#         [0.95534159, 0.42254002],
#         [0.07538986, 0.43134689]]),
#  '03_aut_id_old|ground_truth|PS|PS03_30.json': array([[0.00197001, 0.08685077],
#         [0.94657552, 0.09938623],
#         [0.93645738, 0.41370228],
#         [0.04438032, 0.42828495]]),
#  '03_aut_id_old|ground_truth|TA|TA03_26.json': array([[0.08216354, 0.20435486],
#         [0.96180596, 0.20353971],
#         [0.95006612, 0.51203762],
#         [0.08302055, 0.50622585]]),
#  '03_aut_id_old|ground_truth|TA|TA03_27.json': array([[0.10256634, 0.2036128 ],
#         [0.98237379, 0.20207064],
#         [0.97021342, 0.51123501],
#         [0.10097827, 0.50496506]]),
#  '03_aut_id_old|ground_truth|TA|TA03_28.json': array([[0.10694993, 0.20216213],
#         [0.99422512, 0.20376713],
#         [0.98035143, 0.51216965],
#         [0.10641059, 0.50499683]]),
#  '03_aut_id_old|ground_truth|TA|TA03_29.json': array([[0.09412342, 0.19749372],
#         [0.98945862, 0.20122393],
#         [0.97300625, 0.5111795 ],
#         [0.09374474, 0.50190777]]),
#  '03_aut_id_old|ground_truth|TA|TA03_30.json': array([[0.08549596, 0.19106949],
#         [0.98048638, 0.19466364],
#         [0.96227634, 0.50486458],
#         [0.0871854 , 0.49670307]]),
#  '03_aut_id_old|ground_truth|TS|TS03_26.json': array([[0.0672602 , 0.36522053],
#         [0.92291443, 0.37720341],
#         [0.9289525 , 0.66826263],
#         [0.04789647, 0.66872635]]),
#  '03_aut_id_old|ground_truth|TS|TS03_27.json': array([[0.05370119, 0.36910038],
#         [0.89022515, 0.38021332],
#         [0.89918688, 0.66633102],
#         [0.0339548 , 0.66811485]]),
#  '03_aut_id_old|ground_truth|TS|TS03_28.json': array([[0.04227525, 0.55347622],
#         [0.04148512, 0.55315121],
#         [0.04240487, 0.553517  ],
#         [0.04214599, 0.55341057]]),
#  '03_aut_id_old|ground_truth|TS|TS03_29.json': array([[0.0767057 , 0.39250603],
#         [0.88331333, 0.40209251],
#         [0.89301717, 0.68128899],
#         [0.0539041 , 0.68340401]]),
#  '03_aut_id_old|ground_truth|TS|TS03_30.json': array([[0.11265639, 0.38058598],
#         [0.91844815, 0.39595833],
#         [0.9249625 , 0.67597374],
#         [0.08700902, 0.67287712]]),
#  '04_aut_id|ground_truth|CA|CA04_26.json': array([[0.13475388, 0.34384159],
#         [0.79080363, 0.20336906],
#         [0.97966593, 0.42084152],
#         [0.29856649, 0.5762038 ]]),
#  '04_aut_id|ground_truth|CA|CA04_27.json': array([[0.13822783, 0.36495724],
#         [0.79642171, 0.22104942],
#         [0.98722154, 0.43902916],
#         [0.30371382, 0.59868824]]),
#  '04_aut_id|ground_truth|CA|CA04_28.json': array([[0.14146742, 0.39461758],
#         [0.80081638, 0.2489241 ],
#         [0.99270752, 0.46792877],
#         [0.30819736, 0.63021732]]),
#  '04_aut_id|ground_truth|CA|CA04_29.json': array([[0.1456308 , 0.42310326],
#         [0.80902296, 0.27728577],
#         [1.0012601 , 0.49865494],
#         [0.31279524, 0.66245689]]),
#  '04_aut_id|ground_truth|CA|CA04_30.json': array([[0.14523437, 0.44623535],
#         [0.814654  , 0.30086948],
#         [1.00763611, 0.52561401],
#         [0.31211738, 0.68937485]]),
#  '04_aut_id|ground_truth|CS|CS04_26.json': array([[0.0658966 , 0.18590206],
#         [0.71240757, 0.11934158],
#         [0.75373128, 0.34649078],
#         [0.0655651 , 0.40054649]]),
#  '04_aut_id|ground_truth|CS|CS04_27.json': array([[0.06930809, 0.18721546],
#         [0.70571459, 0.1233083 ],
#         [0.74427843, 0.35027119],
#         [0.06383433, 0.40127514]]),
#  '04_aut_id|ground_truth|CS|CS04_28.json': array([[0.05936191, 0.17804094],
#         [0.70597724, 0.11546374],
#         [0.74027873, 0.34570297],
#         [0.05059   , 0.39412846]]),
#  '04_aut_id|ground_truth|CS|CS04_29.json': array([[0.03222613, 0.16823347],
#         [0.69456353, 0.10671837],
#         [0.725059  , 0.33967026],
#         [0.02258692, 0.38691032]]),
#  '04_aut_id|ground_truth|CS|CS04_30.json': array([[-4.66553734e-04,  1.67728424e-01],
#         [ 6.63788452e-01,  1.08882093e-01],
#         [ 6.95007460e-01,  3.42616768e-01],
#         [-1.49737899e-02,  3.89276390e-01]]),
#  '04_aut_id|ground_truth|HA|HA04_26.json': array([[0.06822793, 0.3652858 ],
#         [0.88036262, 0.32397549],
#         [0.93717685, 0.61836967],
#         [0.08060824, 0.65410103]]),
#  '04_aut_id|ground_truth|HA|HA04_27.json': array([[0.07195066, 0.36137188],
#         [0.89126377, 0.32157925],
#         [0.94303365, 0.61912373],
#         [0.08641621, 0.65215622]]),
#  '04_aut_id|ground_truth|HA|HA04_28.json': array([[0.06997506, 0.35234615],
#         [0.89664456, 0.31916424],
#         [0.93849521, 0.6182394 ],
#         [0.0922789 , 0.64484726]]),
#  '04_aut_id|ground_truth|HA|HA04_29.json': array([[0.06562832, 0.34301025],
#         [0.90158942, 0.30883028],
#         [0.93395345, 0.61092175],
#         [0.09813658, 0.63633949]]),
#  '04_aut_id|ground_truth|HA|HA04_30.json': array([[0.06390718, 0.33745438],
#         [0.91050639, 0.30597422],
#         [0.92951389, 0.60797497],
#         [0.10755208, 0.62785297]]),
#  '04_aut_id|ground_truth|HS|HS04_26.json': array([[0.07820723, 0.30854546],
#         [0.98614176, 0.37564548],
#         [0.89625034, 0.67409531],
#         [0.02581232, 0.63612991]]),
#  '04_aut_id|ground_truth|HS|HS04_27.json': array([[0.08123288, 0.30606483],
#         [0.96870978, 0.37394394],
#         [0.89957425, 0.68209671],
#         [0.01452142, 0.62575462]]),
#  '04_aut_id|ground_truth|HS|HS04_28.json': array([[0.10008883, 0.30396189],
#         [0.96169406, 0.37033539],
#         [0.90804491, 0.67454048],
#         [0.02739758, 0.62159927]]),
#  '04_aut_id|ground_truth|HS|HS04_29.json': array([[0.10547253, 0.28963522],
#         [0.99098918, 0.35576641],
#         [0.95000705, 0.67199066],
#         [0.02586505, 0.60770744]]),
#  '04_aut_id|ground_truth|HS|HS04_30.json': array([[ 0.0849188 ,  0.29387571],
#         [ 0.98504089,  0.3519685 ],
#         [ 0.94917765,  0.6736071 ],
#         [-0.01416665,  0.61543137]]),
#  '04_aut_id|ground_truth|KA|KA04_26.json': array([[0.2285386 , 0.43526497],
#         [0.85706285, 0.40902294],
#         [0.87284661, 0.63297844],
#         [0.18194938, 0.64411102]]),
#  '04_aut_id|ground_truth|KA|KA04_27.json': array([[0.23163767, 0.44155815],
#         [0.85584351, 0.41185589],
#         [0.87163744, 0.63517525],
#         [0.18690401, 0.64951736]]),
#  '04_aut_id|ground_truth|KA|KA04_28.json': array([[0.23897051, 0.44913364],
#         [0.85753601, 0.41631153],
#         [0.87365641, 0.63859734],
#         [0.19611972, 0.65624504]]),
#  '04_aut_id|ground_truth|KA|KA04_29.json': array([[0.24870368, 0.45630615],
#         [0.86205017, 0.42072441],
#         [0.88033223, 0.64286331],
#         [0.20631539, 0.66223679]]),
#  '04_aut_id|ground_truth|KA|KA04_30.json': array([[0.25583764, 0.4621648 ],
#         [0.86657715, 0.42415829],
#         [0.88553101, 0.64569229],
#         [0.21575144, 0.6675106 ]]),
#  '04_aut_id|ground_truth|KS|KS04_26.json': array([[0.01656209, 0.33619446],
#         [0.9585867 , 0.36038387],
#         [0.87500393, 0.64537682],
#         [0.06148918, 0.62705856]]),
#  '04_aut_id|ground_truth|KS|KS04_27.json': array([[0.05232494, 0.33506733],
#         [0.98307556, 0.36258572],
#         [0.89102926, 0.64165375],
#         [0.08893085, 0.61965717]]),
#  '04_aut_id|ground_truth|KS|KS04_28.json': array([[0.07825106, 0.33026459],
#         [0.99727261, 0.36561665],
#         [0.89939406, 0.63880581],
#         [0.11174674, 0.6119812 ]]),
#  '04_aut_id|ground_truth|KS|KS04_29.json': array([[0.09702443, 0.33496578],
#         [1.02517266, 0.36747364],
#         [0.91882718, 0.64106186],
#         [0.12580741, 0.61573849]]),
#  '04_aut_id|ground_truth|KS|KS04_30.json': array([[0.10079023, 0.35889755],
#         [1.03435499, 0.38718815],
#         [0.92787489, 0.66086304],
#         [0.12472005, 0.64076347]]),
#  '04_aut_id|ground_truth|PA|PA04_26.json': array([[0.22568682, 0.28523848],
#         [0.94982924, 0.39282135],
#         [0.88642761, 0.65039474],
#         [0.10781743, 0.55065327]]),
#  '04_aut_id|ground_truth|PA|PA04_27.json': array([[0.23970191, 0.2861182 ],
#         [0.96328837, 0.39661972],
#         [0.90094727, 0.65494789],
#         [0.12093237, 0.55352295]]),
#  '04_aut_id|ground_truth|PA|PA04_28.json': array([[0.24777396, 0.29110666],
#         [0.9751374 , 0.40452515],
#         [0.91243191, 0.66480362],
#         [0.12664694, 0.5621983 ]]),
#  '04_aut_id|ground_truth|PA|PA04_29.json': array([[0.25611808, 0.29655991],
#         [0.99166124, 0.41251038],
#         [0.92870483, 0.67657959],
#         [0.13228957, 0.57187916]]),
#  '04_aut_id|ground_truth|PA|PA04_30.json': array([[0.25440772, 0.31115667],
#         [0.99161323, 0.42851662],
#         [0.92838881, 0.69334999],
#         [0.12803872, 0.58849823]]),
#  '04_aut_id|ground_truth|PS|PS04_26.json': array([[0.07267354, 0.38595097],
#         [0.91706299, 0.37199032],
#         [0.94083835, 0.68725563],
#         [0.05515558, 0.6870546 ]]),
#  '04_aut_id|ground_truth|PS|PS04_27.json': array([[0.06124422, 0.37465416],
#         [0.92368103, 0.36290409],
#         [0.94290426, 0.68420746],
#         [0.04180709, 0.68005974]]),
#  '04_aut_id|ground_truth|PS|PS04_28.json': array([[0.06467269, 0.36741703],
#         [0.92645684, 0.35765968],
#         [0.94101081, 0.6814782 ],
#         [0.04240326, 0.67442085]]),
#  '04_aut_id|ground_truth|PS|PS04_29.json': array([[0.0712634 , 0.36142567],
#         [0.94370639, 0.35281036],
#         [0.9540823 , 0.67801994],
#         [0.04875618, 0.66941422]]),
#  '04_aut_id|ground_truth|PS|PS04_30.json': array([[0.06311381, 0.35986984],
#         [0.9456444 , 0.3492009 ],
#         [0.95530979, 0.67820084],
#         [0.03987406, 0.6697271 ]]),
#  '04_aut_id|ground_truth|TA|TA04_26.json': array([[0.08221739, 0.33355663],
#         [0.90166165, 0.38674049],
#         [0.83608215, 0.6806308 ],
#         [0.01505674, 0.62196384]]),
#  '04_aut_id|ground_truth|TA|TA04_27.json': array([[0.07664478, 0.32924137],
#         [0.89655348, 0.38980457],
#         [0.82738898, 0.68366493],
#         [0.00777649, 0.6181871 ]]),
#  '04_aut_id|ground_truth|TA|TA04_28.json': array([[ 0.07016722,  0.31451544],
#         [ 0.89728394,  0.38148533],
#         [ 0.82360562,  0.67550102],
#         [-0.00127944,  0.60631634]]),
#  '04_aut_id|ground_truth|TA|TA04_29.json': array([[0.08060705, 0.3025893 ],
#         [0.90610901, 0.36951244],
#         [0.82921197, 0.66318977],
#         [0.00905504, 0.59393227]]),
#  '04_aut_id|ground_truth|TA|TA04_30.json': array([[0.08566916, 0.29455318],
#         [0.91283915, 0.36374104],
#         [0.83276076, 0.6572966 ],
#         [0.01171776, 0.58681911]]),
#  '04_aut_id|ground_truth|TS|TS04_26.json': array([[0.06036749, 0.4215189 ],
#         [0.95907416, 0.44434612],
#         [0.95396898, 0.76189445],
#         [0.02138479, 0.76210236]]),
#  '04_aut_id|ground_truth|TS|TS04_27.json': array([[0.07608732, 0.42647255],
#         [0.9587542 , 0.45287037],
#         [0.9544359 , 0.76645935],
#         [0.03468981, 0.76189964]]),
#  '04_aut_id|ground_truth|TS|TS04_28.json': array([[0.08605324, 0.42598465],
#         [0.9525177 , 0.45395309],
#         [0.95001044, 0.76348068],
#         [0.04468986, 0.75644791]]),
#  '04_aut_id|ground_truth|TS|TS04_29.json': array([[0.08193457, 0.42257538],
#         [0.95065348, 0.44983059],
#         [0.95168755, 0.75648178],
#         [0.03967029, 0.75108467]]),
#  '04_aut_id|ground_truth|TS|TS04_30.json': array([[0.08520419, 0.39793842],
#         [0.94966234, 0.43294746],
#         [0.95104465, 0.73848419],
#         [0.04586281, 0.72656021]]),
#  '05_aze_passport|ground_truth|CA|CA05_26.json': array([[0.14546733, 0.44141228],
#         [0.98469733, 0.54201954],
#         [0.85888204, 0.87469475],
#         [0.03499205, 0.7630986 ]]),
#  '05_aze_passport|ground_truth|CA|CA05_27.json': array([[0.151084  , 0.43172577],
#         [0.98972256, 0.53125484],
#         [0.86392083, 0.86329132],
#         [0.04200327, 0.7518782 ]]),
#  '05_aze_passport|ground_truth|CA|CA05_28.json': array([[0.16028881, 0.42129341],
#         [0.99092916, 0.51913918],
#         [0.86898763, 0.84944382],
#         [0.05290217, 0.73991135]]),
#  '05_aze_passport|ground_truth|CA|CA05_29.json': array([[0.1711476 , 0.40384212],
#         [0.99781854, 0.50147438],
#         [0.87683119, 0.83066643],
#         [0.06466064, 0.72120186]]),
#  '05_aze_passport|ground_truth|CA|CA05_30.json': array([[0.18434642, 0.37647682],
#         [1.00637994, 0.47272255],
#         [0.88803413, 0.80108917],
#         [0.07943915, 0.69227913]]),
#  '05_aze_passport|ground_truth|CS|CS05_26.json': array([[ 0.04917988,  0.32388912],
#         [ 1.02300422,  0.3686367 ],
#         [ 1.05010559,  0.76496132],
#         [-0.05843516,  0.73302467]]),
#  '05_aze_passport|ground_truth|CS|CS05_27.json': array([[ 0.05210434,  0.32667053],
#         [ 1.03149109,  0.37215569],
#         [ 1.05826809,  0.77053734],
#         [-0.05749897,  0.74188515]]),
#  '05_aze_passport|ground_truth|CS|CS05_28.json': array([[ 0.05150039,  0.33179119],
#         [ 1.03326192,  0.37817532],
#         [ 1.06086778,  0.77868813],
#         [-0.05769085,  0.74832169]]),
#  '05_aze_passport|ground_truth|CS|CS05_29.json': array([[ 0.05837877,  0.34088512],
#         [ 1.03548652,  0.38424976],
#         [ 1.06439643,  0.78348465],
#         [-0.04968301,  0.75450546]]),
#  '05_aze_passport|ground_truth|CS|CS05_30.json': array([[ 0.06489509,  0.34740776],
#         [ 1.02406664,  0.39227612],
#         [ 1.05469293,  0.78534195],
#         [-0.04057961,  0.75375793]]),
#  '05_aze_passport|ground_truth|HA|HA05_26.json': array([[0.05916693, 0.31546047],
#         [0.99558153, 0.27174778],
#         [1.03928636, 0.65806488],
#         [0.08235224, 0.67910767]]),
#  '05_aze_passport|ground_truth|HA|HA05_27.json': array([[0.0637021 , 0.31903488],
#         [0.99520053, 0.27581461],
#         [1.0509396 , 0.65794258],
#         [0.07651141, 0.68406517]]),
#  '05_aze_passport|ground_truth|HA|HA05_28.json': array([[0.0702534 , 0.32747337],
#         [0.98738024, 0.28430241],
#         [1.06392002, 0.65648994],
#         [0.06771923, 0.6875705 ]]),
#  '05_aze_passport|ground_truth|HA|HA05_29.json': array([[0.07103777, 0.3261747 ],
#         [0.98529616, 0.28595491],
#         [1.06561428, 0.65394783],
#         [0.06297658, 0.68464714]]),
#  '05_aze_passport|ground_truth|HA|HA05_30.json': array([[0.07331406, 0.32046722],
#         [0.98470323, 0.28338421],
#         [1.06367784, 0.64799706],
#         [0.05795051, 0.6760112 ]]),
#  '05_aze_passport|ground_truth|HS|HS05_26.json': array([[0.07842519, 0.38932194],
#         [0.89896993, 0.42741386],
#         [0.91707079, 0.74822418],
#         [0.03841505, 0.76388611]]),
#  '05_aze_passport|ground_truth|HS|HS05_27.json': array([[0.06584122, 0.37941471],
#         [0.90383959, 0.40910126],
#         [0.90688497, 0.72877373],
#         [0.05022093, 0.75600029]]),
#  '05_aze_passport|ground_truth|HS|HS05_28.json': array([[0.05868065, 0.37901917],
#         [0.90905972, 0.40096024],
#         [0.89450582, 0.71701469],
#         [0.05474651, 0.75285774]]),
#  '05_aze_passport|ground_truth|HS|HS05_29.json': array([[0.05560481, 0.38311092],
#         [0.91575399, 0.3979258 ],
#         [0.90777907, 0.71761986],
#         [0.05868781, 0.75539444]]),
#  '05_aze_passport|ground_truth|HS|HS05_30.json': array([[0.06325868, 0.39008514],
#         [0.93238308, 0.3970612 ],
#         [0.93664103, 0.727957  ],
#         [0.06604358, 0.75549622]]),
#  '05_aze_passport|ground_truth|KA|KA05_26.json': array([[0.05541521, 0.41585125],
#         [0.92682943, 0.31953259],
#         [1.02591187, 0.65547523],
#         [0.19212196, 0.73737938]]),
#  '05_aze_passport|ground_truth|KA|KA05_27.json': array([[0.04543572, 0.41148109],
#         [0.91284939, 0.31801197],
#         [1.0089013 , 0.65243645],
#         [0.17857061, 0.73216637]]),
#  '05_aze_passport|ground_truth|KA|KA05_28.json': array([[0.04132805, 0.40866074],
#         [0.89752916, 0.31942251],
#         [0.98955688, 0.65001328],
#         [0.16873013, 0.72632767]]),
#  '05_aze_passport|ground_truth|KA|KA05_29.json': array([[0.04221388, 0.4035281 ],
#         [0.88670566, 0.32041565],
#         [0.97178738, 0.64702522],
#         [0.1622386 , 0.71850426]]),
#  '05_aze_passport|ground_truth|KA|KA05_30.json': array([[0.04543947, 0.39446125],
#         [0.88065626, 0.31739223],
#         [0.95959846, 0.64124557],
#         [0.15773098, 0.70744354]]),
#  '05_aze_passport|ground_truth|KS|KS05_26.json': array([[0.11075149, 0.34745064],
#         [0.97418382, 0.36293472],
#         [0.9640842 , 0.7204538 ],
#         [0.06149705, 0.69074722]]),
#  '05_aze_passport|ground_truth|KS|KS05_27.json': array([[0.10470991, 0.34714714],
#         [0.97467685, 0.3652726 ],
#         [0.96623623, 0.72534927],
#         [0.05000768, 0.69428406]]),
#  '05_aze_passport|ground_truth|KS|KS05_28.json': array([[0.09579525, 0.35487225],
#         [0.97361294, 0.37428616],
#         [0.97028849, 0.73252151],
#         [0.03370674, 0.70583076]]),
#  '05_aze_passport|ground_truth|KS|KS05_29.json': array([[0.09801052, 0.36657471],
#         [0.97202352, 0.3874897 ],
#         [0.97523817, 0.74291672],
#         [0.02990329, 0.71786987]]),
#  '05_aze_passport|ground_truth|KS|KS05_30.json': array([[0.09280328, 0.36070538],
#         [0.95671095, 0.38875294],
#         [0.96829454, 0.74019524],
#         [0.02376614, 0.71166504]]),
#  '05_aze_passport|ground_truth|PA|PA05_26.json': array([[ 0.0521993 ,  0.34681946],
#         [ 0.91803365,  0.35428455],
#         [ 0.90826348,  0.71850044],
#         [-0.0483507 ,  0.6821125 ]]),
#  '05_aze_passport|ground_truth|PA|PA05_27.json': array([[ 0.07299593,  0.34746208],
#         [ 0.92932448,  0.35052631],
#         [ 0.91633681,  0.71082146],
#         [-0.02674084,  0.67726578]]),
#  '05_aze_passport|ground_truth|PA|PA05_28.json': array([[ 0.08524377,  0.35192768],
#         [ 0.93429938,  0.35418034],
#         [ 0.91962619,  0.71267593],
#         [-0.01594299,  0.67904991]]),
#  '05_aze_passport|ground_truth|PA|PA05_29.json': array([[ 0.0942434 ,  0.35373665],
#         [ 0.94125692,  0.35718487],
#         [ 0.9258709 ,  0.71495659],
#         [-0.00807401,  0.67944901]]),
#  '05_aze_passport|ground_truth|PA|PA05_30.json': array([[ 0.09297448,  0.35124447],
#         [ 0.94395237,  0.35482456],
#         [ 0.92482103,  0.71450928],
#         [-0.01196361,  0.67660278]]),
#  '05_aze_passport|ground_truth|PS|PS05_26.json': array([[0.01990399, 0.28992428],
#         [0.92687222, 0.28612467],
#         [0.94832296, 0.6262204 ],
#         [0.06161469, 0.66657997]]),
#  '05_aze_passport|ground_truth|PS|PS05_27.json': array([[0.01903162, 0.27331766],
#         [0.92637777, 0.27356487],
#         [0.95305366, 0.61282112],
#         [0.06934901, 0.6545565 ]]),
#  '05_aze_passport|ground_truth|PS|PS05_28.json': array([[0.01013998, 0.25319679],
#         [0.92678318, 0.24992104],
#         [0.96639072, 0.59233269],
#         [0.06764856, 0.63797035]]),
#  '05_aze_passport|ground_truth|PS|PS05_29.json': array([[-0.00600363,  0.23613947],
#         [ 0.92714986,  0.22775793],
#         [ 0.96986172,  0.57691471],
#         [ 0.05693295,  0.62326881]]),
#  '05_aze_passport|ground_truth|PS|PS05_30.json': array([[0.10280988, 0.84633812],
#         [0.12784486, 0.84666512],
#         [0.09574236, 0.84712013],
#         [0.09490339, 0.84544487]]),
#  '05_aze_passport|ground_truth|TA|TA05_26.json': array([[0.04189721, 0.38817318],
#         [0.85029073, 0.3441993 ],
#         [0.93070943, 0.66627472],
#         [0.08573029, 0.7144017 ]]),
#  '05_aze_passport|ground_truth|TA|TA05_27.json': array([[0.04403108, 0.37147736],
#         [0.85610853, 0.32666119],
#         [0.9358332 , 0.64974983],
#         [0.08948009, 0.69838814]]),
#  '05_aze_passport|ground_truth|TA|TA05_28.json': array([[0.04438741, 0.35631298],
#         [0.86059299, 0.3115349 ],
#         [0.94017415, 0.63524517],
#         [0.09003347, 0.6840007 ]]),
#  '05_aze_passport|ground_truth|TA|TA05_29.json': array([[0.04013176, 0.3430611 ],
#         [0.8596993 , 0.2983202 ],
#         [0.93849582, 0.62219082],
#         [0.08557249, 0.67111572]]),
#  '05_aze_passport|ground_truth|TA|TA05_30.json': array([[0.03541581, 0.32868214],
#         [0.85834459, 0.28367599],
#         [0.9374783 , 0.60886692],
#         [0.08167607, 0.65820511]]),
#  '05_aze_passport|ground_truth|TS|TS05_26.json': array([[0.06091028, 0.19911224],
#         [0.96462124, 0.24100771],
#         [0.96204332, 0.585975  ],
#         [0.04025826, 0.5742503 ]]),
#  '05_aze_passport|ground_truth|TS|TS05_27.json': array([[0.03421957, 0.1919224 ],
#         [0.94003906, 0.22977104],
#         [0.94635396, 0.57261269],
#         [0.01958774, 0.56701851]]),
#  '05_aze_passport|ground_truth|TS|TS05_28.json': array([[0.04061955, 0.18041203],
#         [0.94119541, 0.21451323],
#         [0.94968072, 0.55804146],
#         [0.02888448, 0.55544437]]),
#  '05_aze_passport|ground_truth|TS|TS05_29.json': array([[0.04663838, 0.17482872],
#         [0.94678663, 0.20718048],
#         [0.95425083, 0.54960274],
#         [0.03544368, 0.5479068 ]]),
#  '05_aze_passport|ground_truth|TS|TS05_30.json': array([[0.05603247, 0.17407236],
#         [0.94661418, 0.20794476],
#         [0.95623522, 0.5475161 ],
#         [0.04420647, 0.54394711]]),
#  '06_bra_passport|ground_truth|CA|CA06_26.json': array([[0.11252798, 0.36180843],
#         [0.8432291 , 0.31334249],
#         [0.90094604, 0.60661209],
#         [0.16512714, 0.64825378]]),
#  '06_bra_passport|ground_truth|CA|CA06_27.json': array([[0.10433885, 0.36495892],
#         [0.84054599, 0.31941412],
#         [0.89536845, 0.61381413],
#         [0.151362  , 0.65306656]]),
#  '06_bra_passport|ground_truth|CA|CA06_28.json': array([[0.08871615, 0.36089687],
#         [0.8291531 , 0.32027431],
#         [0.88020264, 0.61739868],
#         [0.12953467, 0.65126648]]),
#  '06_bra_passport|ground_truth|CA|CA06_29.json': array([[0.07734229, 0.35515423],
#         [0.81686293, 0.31724073],
#         [0.86242452, 0.61557552],
#         [0.1116773 , 0.64446625]]),
#  '06_bra_passport|ground_truth|CA|CA06_30.json': array([[0.06997379, 0.34776924],
#         [0.80577928, 0.31456507],
#         [0.84535177, 0.61255901],
#         [0.0959305 , 0.63674698]]),
#  '06_bra_passport|ground_truth|CS|CS06_26.json': array([[ 0.02015554,  0.23121374],
#         [ 0.94331685,  0.25768148],
#         [ 0.94489983,  0.62241703],
#         [-0.05497702,  0.59749786]]),
#  '06_bra_passport|ground_truth|CS|CS06_27.json': array([[ 0.02321906,  0.23845533],
#         [ 0.94880168,  0.26687883],
#         [ 0.95029053,  0.63231304],
#         [-0.054017  ,  0.60679691]]),
#  '06_bra_passport|ground_truth|CS|CS06_28.json': array([[ 0.01514325,  0.24953049],
#         [ 0.94949856,  0.27491196],
#         [ 0.953821  ,  0.64381638],
#         [-0.06425138,  0.62274464]]),
#  '06_bra_passport|ground_truth|CS|CS06_29.json': array([[ 4.95958924e-04,  2.63914337e-01],
#         [ 9.45951131e-01,  2.89819660e-01],
#         [ 9.52916667e-01,  6.64501572e-01],
#         [-7.73942057e-02,  6.44727859e-01]]),
# ...
#         [0.55375003, 0.55143108],
#         [0.5537439 , 0.55141327],
#         [0.55374776, 0.55143162]]),
#  '19_esp_drvlic|ground_truth|HS|HS19_26.json': array([[-0.00149558,  0.39724632],
#         [ 0.8601083 ,  0.38553123],
#         [ 0.87780273,  0.68585846],
#         [ 0.00514387,  0.70114464]]),
#  '19_esp_drvlic|ground_truth|HS|HS19_27.json': array([[0.00532429, 0.39913708],
#         [0.86500712, 0.3993832 ],
#         [0.86674323, 0.70012466],
#         [0.00129567, 0.70227875]]),
#  '19_esp_drvlic|ground_truth|HS|HS19_28.json': array([[ 0.0277193 ,  0.38112095],
#         [ 0.88584391,  0.40907722],
#         [ 0.86223145,  0.70920715],
#         [-0.0018726 ,  0.68755272]]),
#  '19_esp_drvlic|ground_truth|HS|HS19_29.json': array([[0.07155921, 0.36755245],
#         [0.9253359 , 0.40441753],
#         [0.88738898, 0.70189087],
#         [0.03133733, 0.67109474]]),
#  '19_esp_drvlic|ground_truth|HS|HS19_30.json': array([[0.10520805, 0.35831944],
#         [0.95004917, 0.40185608],
#         [0.9085867 , 0.69910645],
#         [0.06250795, 0.65670784]]),
#  '19_esp_drvlic|ground_truth|KA|KA19_26.json': array([[0.09089823, 0.41790413],
#         [0.88505663, 0.39986099],
#         [0.90424194, 0.67998085],
#         [0.10780486, 0.69533394]]),
#  '19_esp_drvlic|ground_truth|KA|KA19_27.json': array([[0.56714515, 0.63039047],
#         [0.56658325, 0.63026852],
#         [0.56605747, 0.62977268],
#         [0.56904934, 0.63198463]]),
#  '19_esp_drvlic|ground_truth|KA|KA19_28.json': array([[0.11152474, 0.42318825],
#         [0.88678182, 0.40070171],
#         [0.91434781, 0.67573158],
#         [0.12774127, 0.69627502]]),
#  '19_esp_drvlic|ground_truth|KA|KA19_29.json': array([[0.12585234, 0.43700153],
#         [0.88955098, 0.4110807 ],
#         [0.92331896, 0.68262154],
#         [0.14056129, 0.70591141]]),
#  '19_esp_drvlic|ground_truth|KA|KA19_30.json': array([[0.77254157, 0.59556786],
#         [0.75720486, 0.59983475],
#         [0.75613627, 0.60191109],
#         [0.75589403, 0.60086613]]),
#  '19_esp_drvlic|ground_truth|KS|KS19_26.json': array([[-0.00761152,  0.34079304],
#         [ 0.93001275,  0.32156937],
#         [ 0.94459771,  0.63376434],
#         [ 0.03757214,  0.67439423]]),
#  '19_esp_drvlic|ground_truth|KS|KS19_27.json': array([[-0.01369326,  0.34012478],
#         [ 0.93809699,  0.31981869],
#         [ 0.9519142 ,  0.63910366],
#         [ 0.02843479,  0.67523048]]),
#  '19_esp_drvlic|ground_truth|KS|KS19_28.json': array([[-0.01939253,  0.33891792],
#         [ 0.93593736,  0.32420864],
#         [ 0.94404433,  0.64619225],
#         [ 0.01498286,  0.67224167]]),
#  '19_esp_drvlic|ground_truth|KS|KS19_29.json': array([[-0.01501471,  0.33355263],
#         [ 0.93072306,  0.32629509],
#         [ 0.93226101,  0.64877159],
#         [ 0.01004623,  0.66355606]]),
#  '19_esp_drvlic|ground_truth|KS|KS19_30.json': array([[-0.00130425,  0.33167389],
#         [ 0.931234  ,  0.3269688 ],
#         [ 0.92627984,  0.65010315],
#         [ 0.01528593,  0.65561455]]),
#  '19_esp_drvlic|ground_truth|PA|PA19_26.json': array([[-0.14490083,  0.23182974],
#         [ 0.94750312,  0.26254812],
#         [ 0.8808018 ,  0.62661835],
#         [-0.12205777,  0.60170216]]),
#  '19_esp_drvlic|ground_truth|PA|PA19_27.json': array([[-0.09918048,  0.22068148],
#         [ 0.97961202,  0.25474257],
#         [ 0.91517904,  0.61277058],
#         [-0.08269892,  0.58161919]]),
#  '19_esp_drvlic|ground_truth|PA|PA19_28.json': array([[-0.11506643,  0.22176214],
#         [ 0.93091288,  0.25165956],
#         [ 0.88066013,  0.60061146],
#         [-0.10178651,  0.57077892]]),
#  '19_esp_drvlic|ground_truth|PA|PA19_29.json': array([[-0.13779161,  0.23344463],
#         [ 0.89332018,  0.25853464],
#         [ 0.8348744 ,  0.60298363],
#         [-0.115893  ,  0.57278252]]),
#  '19_esp_drvlic|ground_truth|PA|PA19_30.json': array([[-0.14262936,  0.24487736],
#         [ 0.86095479,  0.26968073],
#         [ 0.8087125 ,  0.60673241],
#         [-0.12213736,  0.5750404 ]]),
#  '19_esp_drvlic|ground_truth|PS|PS19_26.json': array([[0.14081212, 0.52168636],
#         [0.89437642, 0.54085468],
#         [0.86360318, 0.79476967],
#         [0.12673266, 0.77912498]]),
#  '19_esp_drvlic|ground_truth|PS|PS19_27.json': array([[0.1381788 , 0.51866196],
#         [0.89424405, 0.53904629],
#         [0.85767734, 0.78987228],
#         [0.12577604, 0.77905945]]),
#  '19_esp_drvlic|ground_truth|PS|PS19_28.json': array([[0.11803218, 0.51740055],
#         [0.88484694, 0.53100437],
#         [0.85327684, 0.78144112],
#         [0.10526821, 0.78768539]]),
#  '19_esp_drvlic|ground_truth|PS|PS19_29.json': array([[0.09964066, 0.51664162],
#         [0.85497477, 0.52338531],
#         [0.83925815, 0.77367081],
#         [0.08737224, 0.79874016]]),
#  '19_esp_drvlic|ground_truth|PS|PS19_30.json': array([[0.09396223, 0.5173558 ],
#         [0.82591465, 0.51786652],
#         [0.83059916, 0.76759155],
#         [0.0845394 , 0.80689278]]),
#  '19_esp_drvlic|ground_truth|TA|TA19_26.json': array([[0.05227458, 0.36004883],
#         [0.86336182, 0.35745117],
#         [0.87062181, 0.65235504],
#         [0.03792018, 0.64387993]]),
#  '19_esp_drvlic|ground_truth|TA|TA19_27.json': array([[0.07403152, 0.34079929],
#         [0.88115682, 0.33767311],
#         [0.89072951, 0.63074623],
#         [0.05838328, 0.62221916]]),
#  '19_esp_drvlic|ground_truth|TA|TA19_28.json': array([[0.08136308, 0.32406689],
#         [0.88569444, 0.32030602],
#         [0.89355421, 0.60881676],
#         [0.06649403, 0.60236404]]),
#  '19_esp_drvlic|ground_truth|TA|TA19_29.json': array([[0.07917394, 0.31340519],
#         [0.87869615, 0.30716381],
#         [0.8872503 , 0.59355576],
#         [0.06358444, 0.59006821]]),
#  '19_esp_drvlic|ground_truth|TA|TA19_30.json': array([[0.07918599, 0.30954342],
#         [0.87264648, 0.29931164],
#         [0.88365295, 0.58329987],
#         [0.06631176, 0.58401119]]),
#  '19_esp_drvlic|ground_truth|TS|TS19_26.json': array([[0.03031517, 0.32110168],
#         [0.96232971, 0.34156208],
#         [0.97834785, 0.6617556 ],
#         [0.00113032, 0.66623825]]),
#  '19_esp_drvlic|ground_truth|TS|TS19_27.json': array([[0.0336285 , 0.32213066],
#         [0.94452772, 0.34547882],
#         [0.95604201, 0.65698669],
#         [0.00968795, 0.65906006]]),
#  '19_esp_drvlic|ground_truth|TS|TS19_28.json': array([[0.03401549, 0.32234901],
#         [0.92715583, 0.34563629],
#         [0.94145854, 0.65069199],
#         [0.00974299, 0.65095131]]),
#  '19_esp_drvlic|ground_truth|TS|TS19_29.json': array([[ 0.01782604,  0.32045967],
#         [ 0.89702942,  0.3460125 ],
#         [ 0.91128479,  0.64484657],
#         [-0.00672873,  0.64824356]]),
#  '19_esp_drvlic|ground_truth|TS|TS19_30.json': array([[ 0.01879453,  0.32436405],
#         [ 0.88789659,  0.34576828],
#         [ 0.90808784,  0.64320335],
#         [-0.00629303,  0.65151192]]),
#  '20_esp_id_new|ground_truth|CA|CA20_26.json': array([[0.07864032, 0.27185518],
#         [0.82866774, 0.28772249],
#         [0.80444295, 0.54884792],
#         [0.08315207, 0.53160896]]),
#  '20_esp_id_new|ground_truth|CA|CA20_27.json': array([[0.07179544, 0.25561354],
#         [0.83634576, 0.27290442],
#         [0.80665059, 0.53802395],
#         [0.07542519, 0.51931488]]),
#  '20_esp_id_new|ground_truth|CA|CA20_28.json': array([[0.06542397, 0.24257664],
#         [0.84139194, 0.26110857],
#         [0.80773438, 0.52963993],
#         [0.07046574, 0.50948483]]),
#  '20_esp_id_new|ground_truth|CA|CA20_29.json': array([[0.06495899, 0.22866726],
#         [0.85260308, 0.2473752 ],
#         [0.81397244, 0.52022583],
#         [0.07068565, 0.49905094]]),
#  '20_esp_id_new|ground_truth|CA|CA20_30.json': array([[0.05913978, 0.21130749],
#         [0.86196221, 0.23208179],
#         [0.82260864, 0.50926796],
#         [0.06700236, 0.48766209]]),
#  '20_esp_id_new|ground_truth|CS|CS20_26.json': array([[ 0.04881521,  0.56634895],
#         [ 0.85206048,  0.57315353],
#         [ 0.92325541,  0.87457314],
#         [-0.00494085,  0.90525841]]),
#  '20_esp_id_new|ground_truth|CS|CS20_27.json': array([[0.06160696, 0.56307369],
#         [0.86329536, 0.57473728],
#         [0.93793742, 0.87768639],
#         [0.00631841, 0.90333626]]),
#  '20_esp_id_new|ground_truth|CS|CS20_28.json': array([[0.0700804 , 0.56467709],
#         [0.86857734, 0.5753009 ],
#         [0.94264011, 0.87539619],
#         [0.01676061, 0.90119324]]),
#  '20_esp_id_new|ground_truth|CS|CS20_29.json': array([[0.06466316, 0.55712646],
#         [0.86469523, 0.57054382],
#         [0.93973009, 0.8696032 ],
#         [0.01000306, 0.89172173]]),
#  '20_esp_id_new|ground_truth|CS|CS20_30.json': array([[0.06699991, 0.55453453],
#         [0.86299608, 0.56620121],
#         [0.93578084, 0.86453232],
#         [0.01006467, 0.88843422]]),
#  '20_esp_id_new|ground_truth|HA|HA20_26.json': array([[0.04802637, 0.33526402],
#         [0.93563822, 0.34611862],
#         [0.97257657, 0.65346855],
#         [0.04747907, 0.67188637]]),
#  '20_esp_id_new|ground_truth|HA|HA20_27.json': array([[0.03550916, 0.33146317],
#         [0.9472718 , 0.33846855],
#         [0.96750387, 0.65424385],
#         [0.04101668, 0.67400909]]),
#  '20_esp_id_new|ground_truth|HA|HA20_28.json': array([[0.04058074, 0.32496578],
#         [0.96572781, 0.33429893],
#         [0.97612461, 0.65405838],
#         [0.04862011, 0.67362511]]),
#  '20_esp_id_new|ground_truth|HA|HA20_29.json': array([[0.05025207, 0.31793571],
#         [1.00025377, 0.3302536 ],
#         [0.98752482, 0.65451569],
#         [0.05730015, 0.67511475]]),
#  '20_esp_id_new|ground_truth|HA|HA20_30.json': array([[0.05767349, 0.31760229],
#         [1.02142856, 0.33023506],
#         [1.00097351, 0.65534721],
#         [0.06632382, 0.67753784]]),
#  '20_esp_id_new|ground_truth|HS|HS20_26.json': array([[0.04385805, 0.39302223],
#         [0.91309842, 0.40475487],
#         [0.91072171, 0.70107018],
#         [0.03961609, 0.71327789]]),
#  '20_esp_id_new|ground_truth|HS|HS20_27.json': array([[0.03245577, 0.38449234],
#         [0.92439758, 0.39846912],
#         [0.92646132, 0.70396393],
#         [0.02584919, 0.71024643]]),
#  '20_esp_id_new|ground_truth|HS|HS20_28.json': array([[0.02414626, 0.37847717],
#         [0.94734029, 0.3788559 ],
#         [0.9561655 , 0.70641273],
#         [0.01613143, 0.70994095]]),
#  '20_esp_id_new|ground_truth|HS|HS20_29.json': array([[0.01843403, 0.37052776],
#         [0.95919535, 0.37689903],
#         [0.97149787, 0.70763321],
#         [0.01012935, 0.71355377]]),
#  '20_esp_id_new|ground_truth|HS|HS20_30.json': array([[0.01083516, 0.36213299],
#         [0.98285936, 0.35994308],
#         [1.00003615, 0.70448967],
#         [0.00978223, 0.70965492]]),
#  '20_esp_id_new|ground_truth|KA|KA20_26.json': array([[0.21008798, 0.18091343],
#         [0.99353475, 0.37063274],
#         [0.77818807, 0.63745285],
#         [0.02173478, 0.45794708]]),
#  '20_esp_id_new|ground_truth|KA|KA20_27.json': array([[0.20192963, 0.16994469],
#         [0.99717543, 0.35635178],
#         [0.78351169, 0.6258437 ],
#         [0.01979387, 0.44985813]]),
#  '20_esp_id_new|ground_truth|KA|KA20_28.json': array([[0.19277522, 0.16144999],
#         [0.9946424 , 0.34261318],
#         [0.78564012, 0.61413486],
#         [0.01701757, 0.44360256]]),
#  '20_esp_id_new|ground_truth|KA|KA20_29.json': array([[0.18508135, 0.15508689],
#         [0.98953756, 0.33196678],
#         [0.7847779 , 0.60402569],
#         [0.017508  , 0.43906742]]),
#  '20_esp_id_new|ground_truth|KA|KA20_30.json': array([[0.18212282, 0.15132686],
#         [0.98832492, 0.32332794],
#         [0.78761563, 0.59632282],
#         [0.02037921, 0.43604687]]),
#  '20_esp_id_new|ground_truth|KS|KS20_26.json': array([[0.19595259, 0.30766022],
#         [0.98884644, 0.32192066],
#         [0.98454739, 0.60212971],
#         [0.18181708, 0.58975418]]),
#  '20_esp_id_new|ground_truth|KS|KS20_27.json': array([[0.20366335, 0.30228781],
#         [0.98157057, 0.31483021],
#         [0.97636325, 0.58880035],
#         [0.19096705, 0.5786116 ]]),
#  '20_esp_id_new|ground_truth|KS|KS20_28.json': array([[0.20866326, 0.30535706],
#         [0.9713482 , 0.31451591],
#         [0.96574212, 0.58397408],
#         [0.19699546, 0.57575615]]),
#  '20_esp_id_new|ground_truth|KS|KS20_29.json': array([[0.21772505, 0.30605413],
#         [0.97074822, 0.31727507],
#         [0.96249953, 0.5823769 ],
#         [0.2058411 , 0.57362183]]),
#  '20_esp_id_new|ground_truth|KS|KS20_30.json': array([[0.21604116, 0.30182541],
#         [0.97080512, 0.31383417],
#         [0.96242703, 0.5786982 ],
#         [0.20421483, 0.56960342]]),
#  '20_esp_id_new|ground_truth|PA|PA20_26.json': array([[-0.01193974,  0.56242287],
#         [ 0.94590522,  0.58202667],
#         [ 0.91771417,  0.92250107],
#         [-0.01804017,  0.88687248]]),
#  '20_esp_id_new|ground_truth|PA|PA20_27.json': array([[0.01366832, 0.55007664],
#         [0.97065681, 0.57492207],
#         [0.94482273, 0.91284126],
#         [0.00507814, 0.87779205]]),
#  '20_esp_id_new|ground_truth|PA|PA20_28.json': array([[0.01095889, 0.53810188],
#         [0.99234524, 0.56001881],
#         [0.95972643, 0.90043114],
#         [0.00176592, 0.87113701]]),
#  '20_esp_id_new|ground_truth|PA|PA20_29.json': array([[ 0.00432245,  0.52972141],
#         [ 0.99235575,  0.55364288],
#         [ 0.96016025,  0.89330009],
#         [-0.00482983,  0.86496132]]),
#  '20_esp_id_new|ground_truth|PA|PA20_30.json': array([[1.01722982e-02, 5.22027893e-01],
#         [9.97178887e-01, 5.45627327e-01],
#         [9.62785712e-01, 8.85060043e-01],
#         [4.91424733e-04, 8.57567978e-01]]),
#  '20_esp_id_new|ground_truth|PS|PS20_26.json': array([[0.0040342 , 0.3751141 ],
#         [0.86266744, 0.38502296],
#         [0.85649394, 0.67602074],
#         [0.00348697, 0.68918503]]),
#  '20_esp_id_new|ground_truth|PS|PS20_27.json': array([[0.01014912, 0.3724329 ],
#         [0.87799486, 0.3886293 ],
#         [0.87036723, 0.68003143],
#         [0.0084032 , 0.69338661]]),
#  '20_esp_id_new|ground_truth|PS|PS20_28.json': array([[0.01751931, 0.36726131],
#         [0.88794257, 0.38533237],
#         [0.87108887, 0.67466965],
#         [0.01751808, 0.69120827]]),
#  '20_esp_id_new|ground_truth|PS|PS20_29.json': array([[0.01354718, 0.36070251],
#         [0.88836338, 0.38262917],
#         [0.86885315, 0.67005493],
#         [0.01478382, 0.68719017]]),
#  '20_esp_id_new|ground_truth|PS|PS20_30.json': array([[0.00593576, 0.35578228],
#         [0.88620538, 0.37656963],
#         [0.87505283, 0.66837898],
#         [0.00626482, 0.68459778]]),
#  '20_esp_id_new|ground_truth|TA|TA20_26.json': array([[0.03892164, 0.43863117],
#         [0.81729858, 0.32253269],
#         [0.98085097, 0.59375217],
#         [0.14596676, 0.71887428]]),
#  '20_esp_id_new|ground_truth|TA|TA20_27.json': array([[0.02521919, 0.42927311],
#         [0.80659885, 0.3122596 ],
#         [0.96778741, 0.58416954],
#         [0.13360877, 0.70978287]]),
#  '20_esp_id_new|ground_truth|TA|TA20_28.json': array([[0.02009194, 0.41259735],
#         [0.80707086, 0.29393314],
#         [0.96772013, 0.56929142],
#         [0.13202067, 0.69566696]]),
#  '20_esp_id_new|ground_truth|TA|TA20_29.json': array([[0.02365312, 0.39137009],
#         [0.81931905, 0.27060404],
#         [0.97996867, 0.54882095],
#         [0.14002937, 0.67696381]]),
#  '20_esp_id_new|ground_truth|TA|TA20_30.json': array([[0.03646996, 0.37745579],
#         [0.83460103, 0.25521412],
#         [0.99646647, 0.53406528],
#         [0.15397329, 0.66322044]]),
#  '20_esp_id_new|ground_truth|TS|TS20_26.json': array([[0.09548087, 0.26793526],
#         [0.80912367, 0.25709661],
#         [0.80314148, 0.51184231],
#         [0.03412271, 0.50315697]]),
#  '20_esp_id_new|ground_truth|TS|TS20_27.json': array([[ 0.06312912,  0.25736107],
#         [ 0.77579658,  0.25013762],
#         [ 0.77265659,  0.50388023],
#         [-0.00662829,  0.49370426]]),
#  '20_esp_id_new|ground_truth|TS|TS20_28.json': array([[ 0.02801208,  0.25673595],
#         [ 0.74096252,  0.24747204],
#         [ 0.73031481,  0.50065666],
#         [-0.04334731,  0.49331261]]),
#  '20_esp_id_new|ground_truth|TS|TS20_29.json': array([[ 0.03340378,  0.25716106],
#         [ 0.73750203,  0.25122549],
#         [ 0.7223843 ,  0.50321045],
#         [-0.03986904,  0.49256615]]),
#  '20_esp_id_new|ground_truth|TS|TS20_30.json': array([[ 0.05125369,  0.25903534],
#         [ 0.75134128,  0.25468723],
#         [ 0.73026727,  0.50689018],
#         [-0.02366018,  0.49264355]]),
#  ...}

# %%
from course_intro_ocr_t1.metrics import dump_results_dict, measure_crop_accuracy

# %%
dump_results_dict(output_dict, Path() / 'pred.json')

# %%
acc = measure_crop_accuracy(
    Path() / 'pred.json',
    Path() / 'gt.json'
)

# %%
print("Точность кропа: {:1.4f}".format(acc))
# Out:
# Точность кропа: 0.9544
